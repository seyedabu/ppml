# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])
print(plt.plot(xpoints, ypoints))
print(plt.show())
#Points without line
x= np.array([0, 5])
y = np.array([0, 25])
print(plt.plot(x, y, marker='p'))
print(plt.show())
#Multiple points
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
print(plt.plot(xpoints, ypoints))
print(plt.show())
#Default X points
ypoints = np.array([3, 8, 1, 10, 5, 7])
print(plt.plot(ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x000001BB8D2ABA60>]
# None
# [<matplotlib.lines.Line2D object at 0x000001BB8DA43D30>]
# None
# [<matplotlib.lines.Line2D object at 0x000001BB8DAB66D0>]
# None
# [<matplotlib.lines.Line2D object at 0x000001BB8DB15D30>]
# None
